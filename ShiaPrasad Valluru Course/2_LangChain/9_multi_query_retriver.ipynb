# %%
from langchain_community.document_loaders import WebBaseLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma

loader = WebBaseLoader("https://lilianweng.github.io/posts/2023-06-23-agent/")
documents=loader.load()

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
splits = text_splitter.split_documents(documents)

# VectorDB
embedding = OpenAIEmbeddings()
vectordb = Chroma.from_documents(documents=splits, embedding=embedding)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 7
#       4 from langchain_chroma import Chroma
#       6 loader = WebBaseLoader("https://lilianweng.github.io/posts/2023-06-23-agent/")
# ----> 7 documents=loader.load()
#       9 text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
#      10 splits = text_splitter.split_documents(documents)
#
# File d:\Coading\GenAI\ShiaPrasad Valluru Course\.venv\Lib\site-packages\langchain_core\document_loaders\base.py:43, in BaseLoader.load(self)
#      37 def load(self) -> list[Document]:
#      38     """Load data into `Document` objects.
#      39
#      40     Returns:
#      41         The documents.
#      42     """
# ---> 43     return list(self.lazy_load())
#
# File d:\Coading\GenAI\ShiaPrasad Valluru Course\.venv\Lib\site-packages\langchain_community\document_loaders\web_base.py:375, in WebBaseLoader.lazy_load(self)
#     373 """Lazy load text from the url(s) in web_path."""
#     374 for path in self.web_paths:
# --> 375     soup = self._scrape(path, bs_kwargs=self.bs_kwargs)
#     376     text = soup.get_text(**self.bs_get_text_kwargs)
#     377     metadata = _build_metadata(soup, path)
#
# File d:\Coading\GenAI\ShiaPrasad Valluru Course\.venv\Lib\site-packages\langchain_community\document_loaders\web_base.py:347, in WebBaseLoader._scrape(self, url, parser, bs_kwargs)
#     341 def _scrape(
#     342     self,
#     343     url: str,
#     344     parser: Union[str, None] = None,
#     345     bs_kwargs: Optional[dict] = None,
#     346 ) -> Any:
# --> 347     from bs4 import BeautifulSoup
#     349     if parser is None:
#     350         if url.endswith(".xml"):
#
# ModuleNotFoundError: No module named 'bs4'

# %%
# multi query retriever
from langchain_classic.retrievers import MultiQueryRetriever
from langchain_google_genai import ChatGoogleGenerativeAI

question = "What are the approaches of Task Decomposition?"

llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    temperature=0.7,
    timeout=30
)

retriever_from_llm = MultiQueryRetriever.from_llm(
    retriever=vectordb.as_retriever(),
    llm=llm
)

# %%
unique_docs = retriever_from_llm.invoke(question)
unique_docs
